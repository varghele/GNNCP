# %% [markdown]
# # Python Notebook to convert H5 file to graph
# First script to run for the GNN analysis.
# Takes an ".h5" trajectory file from "1_h5_trajectories" as input, and outputs a graph, saved in "2_raw_graphs"

# %%
##IMPORTS
import mdtraj as md
import openmm as mm

import mendeleev as me
from mendeleev.fetch import fetch_table
import re
from itertools import combinations
import numpy as np

import torch
from torch_geometric.data import Data

import time
# Out:
# Warning: importing 'simtk.openmm' is deprecated.  Import 'openmm' instead.

# %%
res = np.load("shooting_results.npz")
np.expand_dims(res["shooting_results"][0], axis=0)
# Out:
# array([[279., 221.]])

# %%
def convert_traj_to_graph(traj_loc, res_loc, save_loc):
    """A function to convert .h5 mdtraj trajectories to graphs.
    Outputs a graph for each frame of the trajectory.
    Uses the Mendeleev package for atomic features:
    https://mendeleev.readthedocs.io/
    """
    # traj_loc: path to MDTRAJ ".h5" file, non-optional
    # save_loc: path to location to save the resulting graph
    
    print("Start conversion")
    total_time=time.time()
    
    #--Load Trajectory
    traj = md.load_hdf5(fname_h5)
    #--Load Targets
    res = np.load(res_loc)
    targ = res["shooting_results"]#[:,1]/500
    
    #--Get length of trajectory
    traj_len = len(traj)
    #--Get xyz coordinates from trajectory
    traj_xyz = traj.xyz
    #--Get atoms from trajectory
    traj_atoms = [i for i in traj.topology.atoms]
    #--Get atom residue names
    traj_residue = [str(i.residue) for i in traj.topology.atoms]
    #--Get atom symbols via python regex (symbols needed for mendeleev or dictionary)
    traj_atoms_sym = [re.findall(r'[A-Za-z]+|\d+',a.name)[0] for a in traj_atoms]
    
    #--Get all unique atom types in trajectory
    unique_atoms = list(np.unique(traj_atoms_sym))
    
    #--Load Mendeleev fetch table where data is stored
    me_table = fetch_table("elements")
    #--Define the atomic features you want as node features ##CURRENTLY DISUSED!
    atomic_feature_names = ["symbol",
                            "atomic_number",
                            "atomic_radius", #mb rm
                            "atomic_volume", #mb rm
                            #"atomic_weight",
                            #"electron_affinity", #mb rm
                            #"vdw_radius",
                            #"dipole_polarizability", #mb rm
                            #"en_pauling" #mb rm
                            ]
    
    #--Set up dictionary for edge feature bound or unbound
    #keys: B,U (bound, unbound)
    #values: [1,0], [0,1] (one-hot encoding of b/u)
    edge_dict = {"B": [1, 0], "U": [0, 1]}
    
    #--Set up dictionary for epsilon and sigma parameters from OpenMM Forcefield
    #dictionary: [sigma, epsilon]
    #https://github.com/openmm/openmmforcefields/blob/ddea4f61d508f0cc06ad09dd29d0943721890038/amber/ffxml/tip3p_standard.xml#L261
    node_feature_dict = {"Li": [0.18263423721876956, 0.1171084864], 
                         "Cl": [0.4477656957373345, 0.14891274399999999], 
                         "H": [1, 0], 
                         "O": [0.31507524065751241, 0.635968]}
    
    
    
    #--Set up NODE tensor for the graph, 
    #only the xyz coordinates change in each frame, left zero here
    basic_nodes=[]
    for at in traj_atoms_sym:
        #nf = me_table[me_table["symbol"]==at][atomic_feature_names[1:]].values.tolist()[0]+[0,0,0]
        nf = node_feature_dict[at]+[0,0,0]
        basic_nodes.append(nf)
    basic_node_attributes = torch.tensor(basic_nodes, dtype=torch.float)
        
        
    #--Set up edge index tensor
    sender_edges = [list(i) for i in combinations(range(traj.n_atoms),2)]
    receiver_edges = [list(i)[::-1] for i in combinations(range(traj.n_atoms),2)]
    
    edge_index = np.array(sender_edges + receiver_edges)
    
    #--Set up EDGE_ATTR tensor for the graph
    #only the distance changes in each frame
    #here we set up the connection type feature
    start=time.time()
    basic_edge_attributes = torch.tensor([edge_dict["U"] if np.unique(np.array(traj_residue)[edge]).shape==(2,) else edge_dict["B"] for edge in edge_index], dtype=torch.float)
    print("basic_edge_attributes caclulated in {}s".format(np.around(time.time()-start,2)))
    basic_edge_attributes = torch.cat([basic_edge_attributes, torch.full((basic_edge_attributes.shape[0],1),fill_value = 0)], dim=1)
    #Make the edge_index a tensor
    edge_index_tensor = torch.tensor(edge_index.T, dtype=torch.long)
    
    #Timestep here
    for timestep in range(traj_len):
        print("Frame {}/{} converted".format(timestep+1,traj_len))
        #Extract XYZ data from one trajectory frame
        xyz_array = traj[timestep].xyz[0]
        #Calculate distances between nodes as edge attribute
        dist = np.sum(np.square(np.abs(xyz_array[edge_index][:,0,:]-xyz_array[edge_index][:,1,:])),axis=1)
        
        #Make a clone of basic nodes and edge attributes
        g_node_attributes = basic_node_attributes.clone().detach()
        g_edge_attributes = basic_edge_attributes.clone().detach()
    
        #Paste into it the values that change for each frame
        g_node_attributes[:,-3:] = torch.tensor(xyz_array,dtype=torch.float)
        g_edge_attributes[:,-1] = torch.tensor(dist)
        
        #Make tensor of target
        targ_tensor = torch.tensor(np.expand_dims(targ[timestep],axis=0), dtype=torch.float)
        
        #Make a graph of the frame
        graph_of_frame = Data(x = g_node_attributes,
                              edge_index = edge_index_tensor,
                              edge_attr = g_edge_attributes,
                              y = targ_tensor)
        #Save the graph
        torch.save(graph_of_frame,save_loc+"graph_f"+str(timestep)+".pt")
    
    print("\n Total run time: {}m".format(np.around((time.time()-total_time)/60,2)))

# %%
fname_h5 = "shooting_points.h5"
fname_npz = "shooting_results.npz"

traj_loc = "aimmd_data/committor_data/"+fname_h5
res_loc = "aimmd_data/committor_data/"+fname_npz
save_loc = "2_raw_graphs/"
#Make graphs
convert_traj_to_graph(traj_loc, res_loc, save_loc)
# Out:
# Start conversion
# basic_edge_attributes caclulated in 224.73s
# Frame 1/1000 converted
# Frame 2/1000 converted
# Frame 3/1000 converted
# Frame 4/1000 converted
# Frame 5/1000 converted
# Frame 6/1000 converted
# Frame 7/1000 converted
# Frame 8/1000 converted
# Frame 9/1000 converted
# Frame 10/1000 converted
# Frame 11/1000 converted
# Frame 12/1000 converted
# Frame 13/1000 converted
# Frame 14/1000 converted
# Frame 15/1000 converted
# Frame 16/1000 converted
# Frame 17/1000 converted
# Frame 18/1000 converted
# Frame 19/1000 converted
# Frame 20/1000 converted
# Frame 21/1000 converted
# Frame 22/1000 converted
# Frame 23/1000 converted
# Frame 24/1000 converted
# Frame 25/1000 converted
# Frame 26/1000 converted
# Frame 27/1000 converted
# Frame 28/1000 converted
# Frame 29/1000 converted
# Frame 30/1000 converted
# Frame 31/1000 converted
# Frame 32/1000 converted
# Frame 33/1000 converted
# Frame 34/1000 converted
# Frame 35/1000 converted
# Frame 519/1000 converted
# Frame 520/1000 converted
# Frame 521/1000 converted
# Frame 522/1000 converted
# Frame 523/1000 converted
# Frame 524/1000 converted
# Frame 525/1000 converted
# Frame 526/1000 converted
# Frame 527/1000 converted
# Frame 528/1000 converted
# Frame 529/1000 converted
# Frame 530/1000 converted
# Frame 531/1000 converted
# Frame 532/1000 converted
# Frame 533/1000 converted
# Frame 534/1000 converted
# Frame 535/1000 converted
# Frame 536/1000 converted
# Frame 537/1000 converted
# Frame 538/1000 converted
# Frame 539/1000 converted
# Frame 540/1000 converted
# Frame 541/1000 converted
# Frame 542/1000 converted
# Frame 543/1000 converted
# Frame 544/1000 converted
# Frame 545/1000 converted
# Frame 546/1000 converted
# Frame 547/1000 converted
# Frame 548/1000 converted
# Frame 549/1000 converted
# Frame 550/1000 converted
# Frame 551/1000 converted
# Frame 552/1000 converted
# Frame 553/1000 converted
# Frame 554/1000 converted
# Frame 555/1000 converted
# Frame 556/1000 converted
# Frame 557/1000 converted
# Frame 558/1000 converted
# Frame 559/1000 converted
# Frame 560/1000 converted
# Frame 561/1000 converted
# Frame 562/1000 converted
# Frame 563/1000 converted
# Frame 564/1000 converted
# Frame 565/1000 converted
# Frame 566/1000 converted
# Frame 567/1000 converted
# Frame 568/1000 converted
# Frame 569/1000 converted
# Frame 570/1000 converted
# Frame 571/1000 converted
# Frame 572/1000 converted
# Frame 573/1000 converted
# Frame 574/1000 converted
# Frame 575/1000 converted
# Frame 576/1000 converted
# Frame 577/1000 converted
# Frame 578/1000 converted
# Frame 579/1000 converted
# Frame 580/1000 converted
# Frame 581/1000 converted
# Frame 582/1000 converted
# Frame 583/1000 converted
# Frame 584/1000 converted
# Frame 585/1000 converted
# Frame 586/1000 converted
# Frame 587/1000 converted
# Frame 588/1000 converted
# Frame 589/1000 converted
# Frame 590/1000 converted
# Frame 591/1000 converted
# Frame 592/1000 converted
# Frame 593/1000 converted
# Frame 594/1000 converted
# Frame 595/1000 converted
# Frame 596/1000 converted
# Frame 597/1000 converted
# Frame 598/1000 converted
# Frame 599/1000 converted
# Frame 600/1000 converted
# Frame 601/1000 converted
# Frame 602/1000 converted
# Frame 603/1000 converted
# Frame 604/1000 converted
# Frame 605/1000 converted
# Frame 606/1000 converted
# Frame 607/1000 converted
# Frame 608/1000 converted
# Frame 609/1000 converted
# Frame 610/1000 converted
# Frame 611/1000 converted
# Frame 612/1000 converted
# Frame 613/1000 converted
# Frame 614/1000 converted
# Frame 615/1000 converted
# Frame 616/1000 converted
# Frame 617/1000 converted
# Frame 618/1000 converted
# Frame 619/1000 converted
# Frame 620/1000 converted
# Frame 621/1000 converted
# Frame 622/1000 converted
# Frame 623/1000 converted
# Frame 624/1000 converted
# Frame 625/1000 converted
# Frame 626/1000 converted
# Frame 627/1000 converted
# Frame 628/1000 converted
# Frame 629/1000 converted
# Frame 630/1000 converted
# Frame 631/1000 converted
# Frame 632/1000 converted
# Frame 633/1000 converted
# Frame 634/1000 converted
# Frame 635/1000 converted
# Frame 636/1000 converted
# Frame 637/1000 converted
# Frame 638/1000 converted
# Frame 639/1000 converted
# Frame 640/1000 converted
# Frame 641/1000 converted
# Frame 642/1000 converted
# Frame 643/1000 converted
# Frame 644/1000 converted
# Frame 645/1000 converted
# Frame 646/1000 converted
# Frame 647/1000 converted
# Frame 648/1000 converted
# Frame 649/1000 converted
# Frame 650/1000 converted
# Frame 651/1000 converted
# Frame 652/1000 converted
# Frame 653/1000 converted
# Frame 654/1000 converted
# Frame 655/1000 converted
# Frame 656/1000 converted
# Frame 657/1000 converted
# Frame 658/1000 converted
# Frame 659/1000 converted
# Frame 660/1000 converted
# Frame 661/1000 converted
# Frame 662/1000 converted
# Frame 663/1000 converted
# Frame 664/1000 converted
# Frame 665/1000 converted
# Frame 666/1000 converted
# Frame 667/1000 converted
# Frame 668/1000 converted
# Frame 669/1000 converted
# Frame 670/1000 converted
# Frame 671/1000 converted
# Frame 672/1000 converted
# Frame 673/1000 converted
# Frame 674/1000 converted
# Frame 675/1000 converted
# Frame 676/1000 converted
# Frame 677/1000 converted
# Frame 678/1000 converted
# Frame 679/1000 converted
# Frame 680/1000 converted
# Frame 681/1000 converted
# Frame 682/1000 converted
# Frame 683/1000 converted
# Frame 684/1000 converted
# Frame 685/1000 converted
# Frame 686/1000 converted
# Frame 687/1000 converted
# Frame 688/1000 converted
# Frame 689/1000 converted
# Frame 690/1000 converted
# Frame 691/1000 converted
# Frame 692/1000 converted
# Frame 693/1000 converted
# Frame 694/1000 converted
# Frame 695/1000 converted
# Frame 696/1000 converted
# Frame 697/1000 converted
# Frame 698/1000 converted
# Frame 699/1000 converted
# Frame 700/1000 converted
# Frame 701/1000 converted
# Frame 702/1000 converted
# Frame 703/1000 converted
# Frame 704/1000 converted
# Frame 705/1000 converted
# Frame 706/1000 converted
# Frame 707/1000 converted
# Frame 708/1000 converted
# Frame 709/1000 converted
# Frame 710/1000 converted
# Frame 711/1000 converted
# Frame 712/1000 converted
# Frame 713/1000 converted
# Frame 714/1000 converted
# Frame 715/1000 converted
# Frame 716/1000 converted
# Frame 717/1000 converted
# Frame 718/1000 converted
# Frame 719/1000 converted
# Frame 720/1000 converted
# Frame 721/1000 converted
# Frame 722/1000 converted
# Frame 723/1000 converted
# Frame 724/1000 converted
# Frame 725/1000 converted
# Frame 726/1000 converted
# Frame 727/1000 converted
# Frame 728/1000 converted
# Frame 729/1000 converted
# Frame 730/1000 converted
# Frame 731/1000 converted
# Frame 732/1000 converted
# Frame 733/1000 converted
# Frame 734/1000 converted
# Frame 735/1000 converted
# Frame 736/1000 converted
# Frame 737/1000 converted
# Frame 738/1000 converted
# Frame 739/1000 converted
# Frame 740/1000 converted
# Frame 741/1000 converted
# Frame 742/1000 converted
# Frame 743/1000 converted
# Frame 744/1000 converted
# Frame 745/1000 converted
# Frame 746/1000 converted
# Frame 747/1000 converted
# Frame 748/1000 converted
# Frame 749/1000 converted
# Frame 750/1000 converted
# Frame 751/1000 converted
# Frame 752/1000 converted
# Frame 753/1000 converted
# Frame 754/1000 converted
# Frame 755/1000 converted
# Frame 756/1000 converted
# Frame 757/1000 converted
# Frame 758/1000 converted
# Frame 759/1000 converted
# Frame 760/1000 converted
# Frame 761/1000 converted
# Frame 762/1000 converted
# Frame 763/1000 converted
# Frame 764/1000 converted
# Frame 765/1000 converted
# Frame 766/1000 converted
# Frame 767/1000 converted
# Frame 768/1000 converted
# Frame 769/1000 converted
# Frame 770/1000 converted
# Frame 771/1000 converted
# Frame 772/1000 converted
# Frame 773/1000 converted
# Frame 774/1000 converted
# Frame 775/1000 converted
# Frame 776/1000 converted
# Frame 777/1000 converted
# Frame 778/1000 converted
# Frame 779/1000 converted
# Frame 780/1000 converted
# Frame 781/1000 converted
# Frame 782/1000 converted
# Frame 783/1000 converted
# Frame 784/1000 converted
# Frame 785/1000 converted
# Frame 786/1000 converted
# Frame 787/1000 converted
# Frame 788/1000 converted
# Frame 789/1000 converted
# Frame 790/1000 converted
# Frame 791/1000 converted
# Frame 792/1000 converted
# Frame 793/1000 converted
# Frame 794/1000 converted
# Frame 795/1000 converted
# Frame 796/1000 converted
# Frame 797/1000 converted
# Frame 798/1000 converted
# Frame 799/1000 converted
# Frame 800/1000 converted
# Frame 801/1000 converted
# Frame 802/1000 converted
# Frame 803/1000 converted
# Frame 804/1000 converted
# Frame 805/1000 converted
# Frame 806/1000 converted
# Frame 807/1000 converted
# Frame 808/1000 converted
# Frame 809/1000 converted
# Frame 810/1000 converted
# Frame 811/1000 converted
# Frame 812/1000 converted
# Frame 813/1000 converted
# Frame 814/1000 converted
# Frame 815/1000 converted
# Frame 816/1000 converted
# Frame 817/1000 converted
# Frame 818/1000 converted
# Frame 819/1000 converted
# Frame 820/1000 converted
# Frame 821/1000 converted
# Frame 822/1000 converted
# Frame 823/1000 converted
# Frame 824/1000 converted
# Frame 825/1000 converted
# Frame 826/1000 converted
# Frame 827/1000 converted
# Frame 828/1000 converted
# Frame 829/1000 converted
# Frame 830/1000 converted
# Frame 831/1000 converted
# Frame 832/1000 converted
# Frame 833/1000 converted
# Frame 834/1000 converted
# Frame 835/1000 converted
# Frame 836/1000 converted
# Frame 837/1000 converted
# Frame 838/1000 converted
# Frame 839/1000 converted
# Frame 840/1000 converted
# Frame 841/1000 converted
# Frame 842/1000 converted
# Frame 843/1000 converted
# Frame 844/1000 converted
# Frame 845/1000 converted
# Frame 846/1000 converted
# Frame 847/1000 converted
# Frame 848/1000 converted
# Frame 849/1000 converted
# Frame 850/1000 converted
# Frame 851/1000 converted
# Frame 852/1000 converted
# Frame 853/1000 converted
# Frame 854/1000 converted
# Frame 855/1000 converted
# Frame 856/1000 converted
# Frame 857/1000 converted
# Frame 858/1000 converted
# Frame 859/1000 converted
# Frame 860/1000 converted
# Frame 861/1000 converted
# Frame 862/1000 converted
# Frame 863/1000 converted
# Frame 864/1000 converted
# Frame 865/1000 converted
# Frame 866/1000 converted
# Frame 867/1000 converted
# Frame 868/1000 converted
# Frame 869/1000 converted
# Frame 870/1000 converted
# Frame 871/1000 converted
# Frame 872/1000 converted
# Frame 873/1000 converted
# Frame 874/1000 converted
# Frame 875/1000 converted
# Frame 876/1000 converted
# Frame 877/1000 converted
# Frame 878/1000 converted
# Frame 879/1000 converted
# Frame 880/1000 converted
# Frame 881/1000 converted
# Frame 882/1000 converted
# Frame 883/1000 converted
# Frame 884/1000 converted
# Frame 885/1000 converted
# Frame 886/1000 converted
# Frame 887/1000 converted
# Frame 888/1000 converted
# Frame 889/1000 converted
# Frame 890/1000 converted
# Frame 891/1000 converted
# Frame 892/1000 converted
# Frame 893/1000 converted
# Frame 894/1000 converted
# Frame 895/1000 converted
# Frame 896/1000 converted
# Frame 897/1000 converted
# Frame 898/1000 converted
# Frame 899/1000 converted
# Frame 900/1000 converted
# Frame 901/1000 converted
# Frame 902/1000 converted
# Frame 903/1000 converted
# Frame 904/1000 converted
# Frame 905/1000 converted
# Frame 906/1000 converted
# Frame 907/1000 converted
# Frame 908/1000 converted
# Frame 909/1000 converted
# Frame 910/1000 converted
# Frame 911/1000 converted
# Frame 912/1000 converted
# Frame 913/1000 converted
# Frame 914/1000 converted
# Frame 915/1000 converted
# Frame 916/1000 converted
# Frame 917/1000 converted
# Frame 918/1000 converted
# Frame 919/1000 converted
# Frame 920/1000 converted
# Frame 921/1000 converted
# Frame 922/1000 converted
# Frame 923/1000 converted
# Frame 924/1000 converted
# Frame 925/1000 converted
# Frame 926/1000 converted
# Frame 927/1000 converted
# Frame 928/1000 converted
# Frame 929/1000 converted
# Frame 930/1000 converted
# Frame 931/1000 converted
# Frame 932/1000 converted
# Frame 933/1000 converted
# Frame 934/1000 converted
# Frame 935/1000 converted
# Frame 936/1000 converted
# Frame 937/1000 converted
# Frame 938/1000 converted
# Frame 939/1000 converted
# Frame 940/1000 converted
# Frame 941/1000 converted
# Frame 942/1000 converted
# Frame 943/1000 converted
# Frame 944/1000 converted
# Frame 945/1000 converted
# Frame 946/1000 converted
# Frame 947/1000 converted
# Frame 948/1000 converted
# Frame 949/1000 converted
# Frame 950/1000 converted
# Frame 951/1000 converted
# Frame 952/1000 converted
# Frame 953/1000 converted
# Frame 954/1000 converted
# Frame 955/1000 converted
# Frame 956/1000 converted
# Frame 957/1000 converted
# Frame 958/1000 converted
# Frame 959/1000 converted
# Frame 960/1000 converted
# Frame 961/1000 converted
# Frame 962/1000 converted
# Frame 963/1000 converted
# Frame 964/1000 converted
# Frame 965/1000 converted
# Frame 966/1000 converted
# Frame 967/1000 converted
# Frame 968/1000 converted
# Frame 969/1000 converted
# Frame 970/1000 converted
# Frame 971/1000 converted
# Frame 972/1000 converted
# Frame 973/1000 converted
# Frame 974/1000 converted
# Frame 975/1000 converted
# Frame 976/1000 converted
# Frame 977/1000 converted
# Frame 978/1000 converted
# Frame 979/1000 converted
# Frame 980/1000 converted
# Frame 981/1000 converted
# Frame 982/1000 converted
# Frame 983/1000 converted
# Frame 984/1000 converted
# Frame 985/1000 converted
# Frame 986/1000 converted
# Frame 987/1000 converted
# Frame 988/1000 converted
# Frame 989/1000 converted
# Frame 990/1000 converted
# Frame 991/1000 converted
# Frame 992/1000 converted
# Frame 993/1000 converted
# Frame 994/1000 converted
# Frame 995/1000 converted
# Frame 996/1000 converted
# Frame 997/1000 converted
# Frame 998/1000 converted
# Frame 999/1000 converted
# Frame 1000/1000 converted
#
#  Total run time: 14.86m
